# %% [markdown]
# <a href="https://colab.research.google.com/github/SeloJumadiko/-data-science-2026/blob/main/Pertemuan1_%5BSelo_Jumadiko%5D_%5B240401010276%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ====================================================

# %%
# SEL 1: Output sederhana
print ("Hello, Data Science")
print ("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
#SEL 2: Variabel dan tipe data dasar
nama      = "Selo Jumadiko"           # String
angkatan  = 2025                      # Interger
ipk       = 3.75                      # Float
aktif     = True                      # Boolean

print(f"Nama    : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK     : {ipk}")
print(f"Aktif   : {aktif}")
# Out:
# Nama    : Selo Jumadiko
# Angkatan: 2025
# IPK     : 3.75
# Aktif   : True

# %%
# SEL 3: List dan Perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"   {i}.  {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#    1.  Python
#    2.  Google Colab
#    3.  Jupyter Notebook
#    4.  Github

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Selo Jumadiko", "informatika", 2025)
print(hasil)
# Out:
# Hai! Saya Selo Jumadiko dari informatika, angkatan 2025.
